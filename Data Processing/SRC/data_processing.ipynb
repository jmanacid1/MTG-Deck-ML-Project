# %%
import pandas as pd

# %%
df = pd.read_csv("../Inputs/fdn_draft_data_10k_rows.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 expansion    event_type  \
# 0             0           0       FDN  PremierDraft
# 1             1           1       FDN  PremierDraft
# 2             2           2       FDN  PremierDraft
# 3             3           3       FDN  PremierDraft
# 4             4           4       FDN  PremierDraft
#
#                            draft_id           draft_time      rank  \
# 0  c296734752c7449592905c452b88688f  2024-11-12 19:09:18  platinum
# 1  c296734752c7449592905c452b88688f  2024-11-12 19:09:18  platinum
# 2  c296734752c7449592905c452b88688f  2024-11-12 19:09:18  platinum
# 3  c296734752c7449592905c452b88688f  2024-11-12 19:09:18  platinum
# 4  c296734752c7449592905c452b88688f  2024-11-12 19:09:18  platinum
#
#    event_match_wins  event_match_losses  pack_number  ...  pool_Wary Thespian  \
# 0                 1                   0            0  ...                   0
# 1                 1                   0            0  ...                   0
# ...

# %%
draft_id_var = df.iloc[201,4]

single_draft_df = df[df['draft_id'] == draft_id_var]

# %%
single_draft_df.loc[single_draft_df['pick_maindeck_rate'] == 1,['pick']]
# Out:
#                            pick
# 168    Rite of the Dragoncaller
# 169             Burst Lightning
# 170          Fiery Annihilation
# 171             Spectral Sailor
# 172          Goblin Negotiation
# 173            Firebrand Archer
# 174            Uncharted Voyage
# 177           Swiftwater Cliffs
# 182         Slumbering Cerberus
# 183  Balmor, Battlemage Captain
# 184              Faebloom Trick
# 185          Fiery Annihilation
# 188  Balmor, Battlemage Captain
# 189            Grappling Kraken
# 190            Firebrand Archer
# 191                 Sure Strike
# 192                 Think Twice
# 193                      Refute
# 196             Arcane Epiphany
# 197         Heartfire Immolator
# 200             Burst Lightning
# 201                 Micromancer
# 202           Skyship Buccaneer
