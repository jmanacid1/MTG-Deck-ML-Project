# %%
import pandas as pd

# %%
df = pd.read_csv("../Inputs/fdn_draft_data_10k_rows.csv")
df.shape
# Out:
# (10000, 588)

# %%
full_draft_df = df.loc[(df['event_match_losses'] == 3) | (df['event_match_wins'] == 7)]
full_draft_df.shape
# Out:
# (9350, 588)

# %%
draft_id_var = df.iloc[201,4]

single_draft_df = df[df['draft_id'] == draft_id_var]

# %%
maindeck_df = single_draft_df.loc[single_draft_df['pick_maindeck_rate'] == 1,['pick']]
maindeck_list = maindeck_df['pick'].tolist()
pool_list = single_draft_df['pick'].tolist()

# %%
output_df = full_draft_df[['draft_id','pick','pick_maindeck_rate']]
output_df.to_pickle(path="../Outputs/processed_fdn_draft_data")
